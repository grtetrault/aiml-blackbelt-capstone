# %% [markdown]
# # 1 - Exploration <a class="anchor" id="top"></a>
# * [Introduction](#intro)
# * [Setup](#setup)
# * [Loading the data](#load-data)
# * [Exploratory visualizations](#viz)
#     * [Distribution of delays](#distr-delays)
#     * [Airports](#airports)
#     * [Reasons for delays](#reason-delay)
#     * [Carriers](#carriers)
#     * [Weather](#weather)

# %% [markdown]
# ## Introduction <a class="anchor" id="intro"></a>
# In this notebook, we will explore the output the data pipeline.
# The resulting data set consists of flight features and statistics spanning several years, where each row represents a flight.
# Further, as the ETL job joins relevant weather data to each flight, we have available to us temperature and precipitation data.
#
# A note before continuing.
# This project is concerned with predicting the delay time for *upcoming* flights.
# With that, we will focus on the relationships between variables that are either known before departure,
# or variables for which reliable forecasts exists (namely weather data).
# We will examine how these variables are related to the realized delay times as well as to each other.

# %% [markdown]
# ## Setup <a class="anchor" id="setup"></a>
# First, we must import relevant Spark modules as well as libraries for statistical analysis and visualizations.
# Note that will also start the Spark application that creates the `SparkSession` and sets it to the `spark` variable.

# %%
# %%cleanup -f

# %%
import pyspark
import pyspark.ml as ml
import pyspark.sql as sql
import pyspark.sql.types as types
import pyspark.sql.functions as F

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")

# %% [markdown]
# ## Loading the data <a class="anchor" id="load-data"></a>
#
# Now, we load the airline data from S3.
# To do this, we must first get the bucket name where the data is stored.
# This variable is stored on the local Sagemaker notebook instance during the `DevEnvironment` stack creation
# and must be explicitly passed to the Spark cluster.

# %%
# %%local
# import json
# with open("/home/ec2-user/.aiml-bb/stack-data.json", "r") as f:
#     data_bucket = json.load(f)["data_bucket"]

# %%
# %%send_to_spark -i data_bucket -t str
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Successfully passed 'data_bucket' as 'data_bucket' to Spark kernel

# %%
join_df = spark.read.parquet(f"s3://{data_bucket}/etl_output/joined_airline_weather_data/")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# %%pretty
# join_df.show(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# <table><tr><th>dest</th><th>origin</th><th>year</th><th>quarter</th><th>month</th><th>day_of_month</th><th>day_of_week</th><th>fl_date</th><th>op_unique_carrier</th><th>op_carrier_airline_id</th><th>op_carrier</th><th>tail_num</th><th>op_carrier_fl_num</th><th>origin_airport_id</th><th>origin_airport_seq_id</th><th>origin_city_market_id</th><th>origin_city_name</th><th>origin_state_abr</th><th>origin_state_fips</th><th>origin_state_nm</th><th>origin_wac</th><th>dest_airport_id</th><th>dest_airport_seq_id</th><th>dest_city_market_id</th><th>dest_city_name</th><th>dest_state_abr</th><th>dest_state_fips</th><th>dest_state_nm</th><th>dest_wac</th><th>crs_dep_time</th><th>dep_time</th><th>dep_delay</th><th>dep_delay_new</th><th>dep_del15</th><th>dep_delay_group</th><th>dep_time_blk</th><th>taxi_out</th><th>wheels_off</th><th>wheels_on</th><th>taxi_in</th><th>crs_arr_time</th><th>arr_time</th><th>arr_delay</th><th>arr_delay_new</th><th>arr_del15</th><th>arr_delay_group</th><th>arr_time_blk</th><th>cancelled</th><th>cancellation_code</th><th>diverted</th><th>crs_elapsed_time</th><th>actual_elapsed_time</th><th>air_time</th><th>flights</th><th>distance</th><th>distance_group</th><th>carrier_delay</th><th>weather_delay</th><th>nas_delay</th><th>security_delay</th><th>late_aircraft_delay</th><th>origin_latitude</th><th>origin_longitude</th><th>origin_in_range_station_ids</th><th>dest_latitude</th><th>dest_longitude</th><th>dest_in_range_station_ids</th><th>date_timestamp</th><th>origin_station_date_timestamp</th><th>origin_station_id</th><th>origin_station_latitude</th><th>origin_station_longitude</th><th>origin_prcp</th><th>origin_snow</th><th>origin_snwd</th><th>origin_tmax</th><th>origin_tmin</th><th>origin_geo_distance</th><th>dest_station_date_timestamp</th><th>dest_station_id</th><th>dest_station_latitude</th><th>dest_station_longitude</th><th>dest_prcp</th><th>dest_snow</th><th>dest_snwd</th><th>dest_tmax</th><th>dest_tmin</th></tr><tr><td>ABE</td><td>ATL</td><td>2011</td><td>1</td><td>1</td><td>25</td><td>2</td><td>2011-01-25</td><td>EV</td><td>20366</td><td>EV</td><td>N906EV</td><td>5578</td><td>10397</td><td>1039703</td><td>30397</td><td>Atlanta, GA</td><td>GA</td><td>13</td><td>Georgia</td><td>34</td><td>10135</td><td>1013501</td><td>30135</td><td>Allentown/Bethleh...</td><td>PA</td><td>42</td><td>Pennsylvania</td><td>23</td><td>2037</td><td>2122.0</td><td>45.0</td><td>45.0</td><td>1.0</td><td>3.0</td><td>2000-2059</td><td>27.0</td><td>2149.0</td><td>2313.0</td><td>4.0</td><td>2238</td><td>2317.0</td><td>39.0</td><td>39.0</td><td>1.0</td><td>2.0</td><td>2200-2259</td><td>0.0</td><td>null</td><td>0.0</td><td>121.0</td><td>115.0</td><td>84.0</td><td>1.0</td><td>692.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>39.0</td><td>33.6367</td><td>-84.428101</td><td>[USW00013874, US1...</td><td>40.652099609375</td><td>-75.44080352783203</td><td>[USW00014737, US1...</td><td>2011-01-25</td><td>2011-01-25</td><td>USW00013874</td><td>33.63</td><td>-84.4417</td><td>127.0</td><td>0.0</td><td>0.0</td><td>61.0</td><td>28.0</td><td>0.7229345980519907</td><td>2011-01-25</td><td>USW00014737</td><td>40.6508</td><td>-75.4492</td><td>0.0</td><td>3.0</td><td>102.0</td><td>11.0</td><td>-89.0</td></tr><tr><td>ABE</td><td>ATL</td><td>2011</td><td>1</td><td>1</td><td>25</td><td>2</td><td>2011-01-25</td><td>EV</td><td>20366</td><td>EV</td><td>N907EV</td><td>5498</td><td>10397</td><td>1039703</td><td>30397</td><td>Atlanta, GA</td><td>GA</td><td>13</td><td>Georgia</td><td>34</td><td>10135</td><td>1013501</td><td>30135</td><td>Allentown/Bethleh...</td><td>PA</td><td>42</td><td>Pennsylvania</td><td>23</td><td>1457</td><td>1455.0</td><td>-2.0</td><td>0.0</td><td>0.0</td><td>-1.0</td><td>1400-1459</td><td>26.0</td><td>1521.0</td><td>1646.0</td><td>3.0</td><td>1657</td><td>1649.0</td><td>-8.0</td><td>0.0</td><td>0.0</td><td>-1.0</td><td>1600-1659</td><td>0.0</td><td>null</td><td>0.0</td><td>120.0</td><td>114.0</td><td>85.0</td><td>1.0</td><t ...

# %% [markdown]
# ## Exploratory visualizations <a class="anchor" id="viz"></a>

# %% [markdown]
# ### Distribution of delays <a class="anchor" id="distr-delay"></a>
# We now examine how the delay times are distributed,
# first by using a histogram of the arrival delay times, and then by converting delay time into a categorical feature.

# %%
# Compute histogram of arrival delays.
n_bins = 50
bin_edges, bin_vals = (
    join_df
    .select("arr_delay")
    .rdd.flatMap(lambda _: _)
    .histogram(n_bins)
)
bin_width = bin_edges[1] - bin_edges[0]
bin_centers = [sum(bin_edges[i-1:i+1]) / 2 for i in range(1, len(bin_edges))]
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Plot histogram of departure delays.
fig, ax = plt.subplots()
ax.bar(
    x=bin_centers, height=bin_vals, width=bin_width
)
ax.set_yscale("log")
ax.set_title("Histogram of arrival delays in minutes")
ax.set_xlabel("Delay in minutes")
ax.set_ylabel("Log of count")
# %matplot plt
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# Note that the above is **log-scaled** on the y-axis.

# %%
# Convert delay time to a categorical variable and summarize.
# Per the following link, flights are classified as on time if 
# their delay is no more than 15 minutes:
# https://www.bts.gov/explore-topics-and-geography/topics/airline-time-performance-and-causes-flight-delays
categorical_delay_count_pdf = (
    join_df
    .withColumn(
        "delay_status", 
        F.when(F.col("arr_delay") > 15, "Delayed")
        .when(F.col("cancelled") == 1, "Cancelled")
        .when(F.col("diverted") == 1, "Diverted")
        .otherwise("OnTime")
    )
    .groupby("delay_status").count()
    .toPandas()
    .sort_values("count")
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# %%pretty
# categorical_delay_count_pdf.head(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#   delay_status     count
# 2     Diverted    153374
# 1    Cancelled   1275124
# 0      Delayed  11238301
# 3       OnTime  53035685

# %%
fig, ax = plt.subplots()
ax.pie(
    categorical_delay_count_pdf["count"].values, 
    labels=categorical_delay_count_pdf["delay_status"].values,
    autopct="%1.1f%%"
)
ax.set_title(f"Pct of flights delayed or cancelled")
ax.axis("equal")
# %matplot plt
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# Class distribution is shown ti be approximately a 4:1 ratio of on time flights to delayed and cancelled flights.
# Depending on model, overand undersampling may need to be considered.

# %% [markdown]
# ### Airports <a class="anchor" id="airports"></a>
# This dataset contains a large number of airports between the origins and destinations.
# Here, we will view how the number of flights compares to these airports.

# %%
# Get the number of inbound and outbound flights
# for each airport.
outbound_airport_count_pdf = (
    join_df
    .groupby("origin").count()
    .toPandas() # Convert to pandas for plotting.
    .rename(columns={
        "count": "NumberOfFlights"
    })
    .sort_values("NumberOfFlights")
)
inbound_airport_count_pdf = (
    join_df
    .groupby("dest").count()
    .toPandas() # Convert to pandas for plotting.
    .rename(columns={ 
        "count": "NumberOfFlights"
    })
    .sort_values("NumberOfFlights")
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# %%pretty
# outbound_airport_count_pdf.head(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#     origin  NumberOfFlights
# 138    TKI                1
# 139    EFD                1
# 107    TUP                1
# 184    ENV                1
# 91     YNG                2

# %%
# %%pretty
# inbound_airport_count_pdf.head(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#     dest  NumberOfFlights
# 123  EFD                1
# 257  FNL                1
# 106  TUP                1
# 90   YNG                2
# 256  TBN               40

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2)
sns.histplot(data=outbound_airport_count_pdf, x="NumberOfFlights", bins=10, ax=ax1)
sns.histplot(data=inbound_airport_count_pdf, x="NumberOfFlights", bins=10, ax=ax2)
ax1.set_ylabel("NumberOfAirports")
ax2.set_ylabel("NumberOfAirports")
ax1.set_title("Number of airports by volume of outbound flights")
ax2.set_title("Number of airports by volume of inbound flights")
fig.tight_layout()
# %matplot plt
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# What this shows is that the vast majority of airports have only account for a small amount of traffic.

# %% [markdown]
# ### Reason for delays <a class="anchor" id="reason-delay"></a>
# We now explore the reason that delays occured and if relationships to variables associated with different reasons (e.g. precipitation).

# %%
# Dictionary for cancellation codes and their respective descriptions.
# Obtained from: https://www.transtats.bts.gov/Download_Lookup.asp?Y11x72=Y_PNaPRYYNgVba
cancellation_code_dict = {
    "A": "Carrier",
    "B": "Weather",
    "C": "National Air System",
    "D": "Security"
}
delay_col_dict = {
    "carrier_delay": "Carrier",
    "weather_delay": "Weather",
    "nas_delay": "National Air System",
    "security_delay": "Security",
    "late_aircraft_delay": "Late Aircraft"
}
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Get the frequencies of different cancellation types.
cancellation_count_pdf = (
    join_df
    .filter(F.col("cancelled")==1)
    .groupby("cancellation_code").count()
    .toPandas()
    .rename(columns={"count": "Count"})
    .sort_values("Count")
)
# Compute columns to display in plot.
cancellation_count_pdf["Description"] = (
    cancellation_count_pdf["cancellation_code"]
    .map(cancellation_code_dict)
)
cancellation_count_pdf["DelayStatus"] = "Cancelled"
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# %%pretty
# cancellation_count_pdf.head(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#   cancellation_code   Count          Description DelayStatus
# 2                 C  188275  National Air System   Cancelled
# 0                 D  238698             Security   Cancelled
# 3                 A  324587              Carrier   Cancelled
# 1                 B  523564              Weather   Cancelled

# %%
# Get the proportional frequences of different delay types.
delay_cols = list(delay_col_dict.keys())
delay_col_sum = sum(F.col(col) for col in delay_cols)
delay_count_pdf = (
    join_df
    .filter(F.col("arr_delay") > 0)
    .select(*[(F.col(col) / delay_col_sum).alias(col) for col in delay_cols])
    .agg( *[F.sum(col).alias(col) for col in delay_cols])
    .toPandas()
    .melt(var_name="delay_col", value_name="count")
    .rename(columns={"count": "Count"})
)
# Compute columns to display in plot.
delay_count_pdf["Description"] = (
    delay_count_pdf["delay_col"]
    .map(delay_col_dict)
)
delay_count_pdf["DelayStatus"] = "Delayed"
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# %%pretty
# delay_count_pdf.head(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#              delay_col         Count          Description DelayStatus
# 0        carrier_delay  3.445982e+06              Carrier     Delayed
# 1        weather_delay  3.766668e+05              Weather     Delayed
# 2            nas_delay  3.579883e+06  National Air System     Delayed
# 3       security_delay  2.428935e+04             Security     Delayed
# 4  late_aircraft_delay  4.248556e+06        Late Aircraft     Delayed

# %%
# Concatenate both count dataframes computed above.
delay_cancellation_count_pdf = (
    pd.concat([cancellation_count_pdf, delay_count_pdf])
    .groupby(["DelayStatus", "Description"], as_index=False)
    .sum()
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# %%pretty
# delay_cancellation_count_pdf.head(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#   DelayStatus          Description         Count
# 0   Cancelled              Carrier  3.245870e+05
# 1   Cancelled  National Air System  1.882750e+05
# 2   Cancelled             Security  2.386980e+05
# 3   Cancelled              Weather  5.235640e+05
# 4     Delayed              Carrier  3.445982e+06

# %%
fig, ax = plt.subplots()
sns.barplot(
    data=delay_cancellation_count_pdf,
    x="Description", y="Count", hue="DelayStatus", ax=ax
)
ax.set_title("Number of delays and cancellations by cause")
plt.setp(ax.get_xticklabels(), rotation=25, ha="right", rotation_mode="anchor")
fig.tight_layout()
# %matplot plt
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# From this, we can see that late aircrafts and the national air system account for the majority of the delays.
# Because we have no data on the national air system,
# and cannot know ahead of time if there are late aircrafts or security concerns,
# we cannot feasibly use these features to predict delay times.
# This leaves us with delays by carrier and weather for use in our predictions.

# %% [markdown]
# ### Carriers <a class="anchor" id="carriers"></a>
# Carriers account for a large portion of the delays is definitively known ahead of time.
# As such, it provides a key feature in our predictions.

# %%
# Get the frequencies of different airlines.
carrier_count_pdf = (
    join_df
    .withColumn(
        "delay_status", 
        F.when(F.col("arr_delay") > 15, "Delayed")
        .when(F.col("cancelled") == 1, "Cancelled")
        .otherwise("OnTime")
    )
    .groupby("delay_status", "op_carrier").count()
    .toPandas() # Convert to pandas for plotting.
    .rename(columns={
        "delay_status": "DelayStatus", 
        "op_carrier": "Carrier", 
        "count": "Count"
    })
    .sort_values("Count")
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# %%pretty
# carrier_count_pdf.head(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#    DelayStatus Carrier  Count
# 5    Cancelled      QX   1614
# 8    Cancelled      CO   2885
# 34   Cancelled      VX   3550
# 40   Cancelled      HA   3602
# 62   Cancelled      FL   7143

# %%
g = sns.FacetGrid(carrier_count_pdf, row="DelayStatus", height=2, aspect=4)
g.map(sns.barplot, "Carrier", "Count")
ax.set_title("Number of flights by carrier")
# %matplot plt
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Get percentage of delayed flights by carrier.
carrier_delay_pct_pdf = (
    join_df
    .withColumn(
        "is_delayed", 
        # Combining delayed and cancelled flights here.
        F.when((F.col("arr_delay") > 15) | (F.col("cancelled") == 1), 1)
    )
    .groupby("op_carrier")
    .agg((F.sum("is_delayed") / F.count("op_carrier")).alias("PctDelayed"))
    .toPandas() # Convert to pandas for plotting.
    .rename(columns={"op_carrier": "Carrier"})
    .sort_values("PctDelayed")
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# %%pretty
# carrier_delay_pct_pdf.head(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#    Carrier  PctDelayed
# 13      HA    0.087394
# 6       QX    0.128533
# 20      DL    0.137957
# 0       AS    0.143331
# 10      FL    0.154447

# %%
fig, ax = plt.subplots()
sns.barplot(
    data=carrier_delay_pct_pdf,
    x="Carrier", y="PctDelayed", ax=ax,
)
ax.set_title("Pct of flights delayed or cancelled by carrier")
fig.tight_layout()
# %matplot plt
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# ### Weather
# Because weather data is left joined to the airline data, we must verify that there is enough not null weather data to provide meaningful insights.
# After this, we'd like to see if there is any correlation between arrival delay time and any of the weather statistics.

# %%
# Check number of flights that contain no weather data.
n_flights_wo_weather = (
    join_df
    .filter(
        F.col("origin_station_id").isNull() | F.col("dest_station_id").isNull()
    )
    .count()
)
pct_flights_wo_weather = (n_flights_wo_weather / join_df.count()) * 100
print(f"Percentage of flights without weather data: {pct_flights_wo_weather:.2f}%")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Percentage of flights without weather data: 1.92%

# %%
# Airports that show no weather data.
airports_wo_weather_df = (
    join_df
    .select(
        F.col("origin").alias("airport"), 
        F.col("fl_date").alias("date"), 
        F.col("origin_station_id").alias("station_id"))
    .filter(F.col("station_id").isNull())
    .union(
        join_df
        .select(
            F.col("dest").alias("airport"),
            F.col("fl_date").alias("date"), 
            F.col("dest_station_id").alias("station_id"))
        .filter(F.col("station_id").isNull())
    )
    .groupby("airport")
    .agg(F.min("date"), F.max("date"))
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# %%pretty
# airports_wo_weather_df.show(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# <table><tr><th>airport</th><th>min(date)</th><th>max(date)</th></tr><tr><td>BGM</td><td>2018-04-15</td><td>2018-04-15</td></tr><tr><td>EAR</td><td>2018-09-05</td><td>2021-10-31</td></tr><tr><td>MQT</td><td>2011-01-01</td><td>2021-07-06</td></tr><tr><td>MYR</td><td>2011-01-01</td><td>2021-10-31</td></tr><tr><td>CWA</td><td>2011-01-01</td><td>2021-10-31</td></tr></table><br /><pre>only showing top 5 rows</pre>

# %% [markdown]
# We see a not insignificant number of airports and dates in this list.
# This is likely due to weather stations generating data inconsistently over time and,
# as we only try to get data from the closeset five stations in the ETL job,
# there is a possibility for there to be a lapse in weather data.
#
# Because the overall percentage of flights without weather data is still low,
# the weather statistics are still viable.

# %%
# Compute correlation between delay and weather metrics.
corr_cols = [
    "arr_delay", 
    "origin_prcp", "origin_snow", "origin_snwd", "origin_tmax", "origin_tmin",
    "dest_prcp", "dest_snow", "dest_snwd", "dest_tmax", "dest_tmin",
]
vec_assembler = ml.feature.VectorAssembler(
    inputCols=corr_cols, 
    outputCol="corr_features", 
    handleInvalid="skip"
)
corr_feature_df = vec_assembler.transform(
    join_df
    .select(*corr_cols)
    .na.fill(0.0, subset=[col for col in corr_cols if "tm" not in col])
)
corr_matrix = ml.stat.Correlation.corr(corr_feature_df, column="corr_features")
corr_ndarray = corr_matrix.collect()[0][0].toArray()
corr_pdf = pd.DataFrame(corr_ndarray, index=corr_cols, columns=corr_cols)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
fig, ax = plt.subplots()
sns.heatmap(
    corr_pdf, 
    vmin=-1.0, vmax=1.0, annot=True, fmt=".2f",
    xticklabels=corr_cols, yticklabels=corr_cols, ax=ax
)
ax.set_title("Correlation between delay and origin/destination weather")
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
fig.tight_layout()
# %matplot plt
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# This, in combination with the results from [reason for delays](#reason-delay),
# suggests that weather is not a strong predictor of delay times.
